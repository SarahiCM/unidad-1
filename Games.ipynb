# %%
import pandas as pd
import numpy as np #Permite trabajar con matriz y otras cosas de datos

# %%
Sales = pd.read_csv("VGSales.csv") 
Sales
# Out:
#         Rank                    Nombre Plataforma    Year     Genre  \
# 0         90                   Pac-Man       2600  1982.0    Puzzle
# 1        240                  Pitfall!       2600  1981.0  Platform
# 2        259                 Asteroids       2600  1980.0   Shooter
# 3        545           Missile Command       2600  1980.0   Shooter
# 4        608            Space Invaders       2600     NaN   Shooter
# ...      ...                       ...        ...     ...       ...
# 16593  16533  Sébastien Loeb Rally Evo       XOne  2016.0    Racing
# 16594  16534             Hitman (2016)       XOne  2016.0    Action
# 16595  16565              Mighty No. 9       XOne  2016.0  Platform
# 16596  16572        Resident Evil 4 HD       XOne  2016.0   Shooter
# 16597  16579         Rugby Challenge 3       XOne  2016.0    Sports
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0                     Atari      7.28      0.45       0.0         0.08
# ...

# %%
consulta2 = Sales[((Sales["Rank"]) >= 16500)]
consulta2
# Out:
#         Rank                                             Nombre Plataforma  \
# 639    16515                                      Balloon Pop 2        3DS
# 640    16531                                  Kiniro no Corda 3        3DS
# 641    16538                                       Mushi Bugyou        3DS
# 642    16545  Mario & Luigi: Paper Jam & Mario Kart 7 Double...        3DS
# 643    16570  Fujiko F. Fujio Characters: Great Assembly! Sl...        3DS
# ...      ...                                                ...        ...
# 16593  16533                           Sébastien Loeb Rally Evo       XOne
# 16594  16534                                      Hitman (2016)       XOne
# 16595  16565                                       Mighty No. 9       XOne
# 16596  16572                                 Resident Evil 4 HD       XOne
# 16597  16579                                  Rugby Challenge 3       XOne
#
# ...

# %%
consulta3 = Sales[((Sales["Publisher"]) == "Atari") & (Sales["Genre"] == "Action")]
consulta3
# Out:
#         Rank                                             Nombre Plataforma  \
# 7        866                        E.T.: The Extra Terrestrial       2600
# 17      1587                                             Combat       2600
# 37      2674                                    Crystal Castles       2600
# 55      3955                                     Midnight Magic       2600
# 58      4017                            Raiders of the Lost Ark       2600
# 66      4234                                       Circus Atari       2600
# 67      4269                                           Gremlins       2600
# 70      4380              Maze Craze: A Game of Cops 'n Robbers       2600
# 82      5066                                           Gravitar       2600
# 97      5800                                       Slot Machine       2600
# 106     6318                                       Flag Capture       2600
# ...

# %%
consulta4 = Sales[((Sales["Plataforma"]) == "NES") & (Sales["Year"] == 1987)]
consulta4
# Out:
#       Rank                                         Nombre Plataforma    Year  \
# 4690   252                Zelda II: The Adventure of Link        NES  1987.0
# 4699   466                       Mike Tyson's Punch-Out!!        NES  1987.0
# 4702   603                              Dragon Warrior II        NES  1987.0
# 4705   648                                  Pro Wrestling        NES  1987.0
# 4710   761                                     Volleyball        NES  1987.0
# 4729  1363                  Pro Yakyuu Family Stadium '87        NES  1987.0
# 4736  1590  Gegege no Kitarou 2: Youkai Gundan no Chousen        NES  1987.0
# 4760  2236                  Castlevania II: Simon's Quest        NES  1987.0
# 4763  2468                                  Final Fantasy        NES  1987.0
# 4765  2549                                       Mega Man        NES  1987.0
#
#              Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %%
#Ejercicio 5
consulta5 = Sales[((((Sales["Plataforma"]) == "PS4") & (Sales["Plataforma"] == "Wii") & (Sales["Plataforma"] == "X360"))
                   & (((Sales["Genre"]) == "Action") & (Sales["Genre"] == "Fighting") & (Sales["Genre"] == "Puzzle")))]
consulta5
# Out:
# Empty DataFrame
# Columns: [Rank, Nombre, Plataforma, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []
